# %% [markdown]
# # BOLT UBC First Byte 2024

# %% [markdown]
# **FlexField Fitness:**
# FlexField Fitness is a company committed to delivering high-quality, flexible, and personalized fitness experiences that meet the evolving needs of its members. The company offers state-of-the-art gyms and digital platforms for fitness. However, it is facing challenges such as defining the right product offering, pricing strategy, and creating a seamless integration of services. FlexField Fitness is exploring potential partnerships to revitalize its brand and attract a broader audience of fitness enthusiasts.
#
# **PulseGear:**
# PulseGear is a brand known for its breathable, sweat-absorbing fabrics and innovative features, such as compression technology and ergonomic design, providing enhanced support during intense physical activities. Despite its initial success, PulseGear is now facing challenges in a competitive athleisure market. The company is exploring partnerships to bring fresh ideas and added value to its product line, aiming to tap into a wider health-conscious audience while renewing its brand appeal.
#
# **Chef's Meal:**
# Chef's Meal is a potential partner of FlexField Fitness in the food delivery industry. The company offers food delivery services and is being considered for a collaboration to create compelling joint products that attract new customers, enhance loyalty, and revitalize the brand.
#
# **CoreBoost:**
# CoreBoost is another potential partner of FlexField Fitness. The company is involved in the gym supplements industry and is being considered for a collaboration to address the challenges of declining customer loyalty. The collaboration aims to develop innovative products or services that resonate with modern consumers' expectations regarding convenience, affordability, and personalization.

# %% [markdown]
# ### Task
# How can FlexField Fitness collaborate with one of these companies (Chef's Meal, PulseGear, or CoreBoost) to create a compelling joint product that attracts new customers, enhances loyalty, and revitalizes the brand?

# %% [markdown]
# ### Guiding Questions
# 1. Based on the datasets provided, what similarities can you identify between the customer behaviours or preferences of FlexField Fitness and the potential partners—Chef's Meal, PulseGear, and CoreBoost? How might these shared characteristics inform strategies for collaboration and enhancing customer
# loyalty?
# 2. What innovative products or services could FlexField Fitness develop in collaboration with one of these companies to address the challenges of
# declining customer loyalty?
# 3. How can the joint offerings be packaged and marketed to resonate with modern consumers' expectations regarding convenience, affordability, and personalization?
# 4. What role can technology play in integrating fitness services with nutrition and supplement delivery to enhance the overall customer experience?
# 5. Should FlexField Fitness and its partner focus on a premium product aimed at a niche market, or create a more accessible offering that appeals to a broader audience?
# 6. How can FlexField Fitness and its chosen partner work together to rebuild brand perception and re-establish trust with their customers?

# %%
import pandas as pd
import numpy as np
import seaborn as sns              
import matplotlib.pyplot as plt

# %%
# read data
fitness = pd.read_csv('flexfield_fitness.csv')
fitness.head(3)
# Out:
#    Customer ID  Gender  Age  Hours at Gym (per week)        Fitness Goal  \
# 0       221958  Female   27                      7.3        Build muscle
# 1       771155  Female   24                      6.2  Endurance training
# 2       231932    Male   22                      7.4            Fat loss
#
#    Gym Membership Length (years)  Calorie Intake
# 0                              4             NaN
# 1                              4          2173.0
# 2                              2          1752.0

# %%
chefsmeal = pd.read_csv('chefsmeal.csv')
chefsmeal.head(3)
# Out:
#    Customer ID  Gender  Age  Hours at Gym (per week)        Fitness Goal  \
# 0       221958  Female   27                      7.3        Build muscle
# 1       771155  Female   24                      6.2  Endurance training
# 2       231932    Male   22                      7.4            Fat loss
#
#    Calorie Intake Dietary Preferences  Average Spend per Meal Order
# 0             NaN         Whole foods                         67.15
# 1          2173.0         Whole foods                         52.94
# 2          1752.0         Whole foods                         38.13

# %%
pulsegear = pd.read_csv('pulsegear.csv')
pulsegear.head(3)
# Out:
#    Customer ID  Gender  Age  Hours at Gym (per week)        Fitness Goal  \
# 0       221958  Female   27                      7.3        Build muscle
# 1       771155  Female   24                      6.2  Endurance training
# 2       231932    Male   22                      7.4            Fat loss
#
#    Average Spend on Apparel ($/year) Type of Apparel Purchased  \
# 0                             643.34               Accessories
# 1                             659.13                   Leisure
# 2                             761.12               Performance
#
#   Primary Apparel Purchase Channel
# 0                    Brand Website
# 1                Physical Retailer
# 2                Physical Retailer

# %%
coreboost = pd.read_csv('coreboost.csv')
coreboost.head(3)
# Out:
#    Customer ID  Gender  Age  Hours at Gym (per week)        Fitness Goal  \
# 0       221958  Female   27                      7.3        Build muscle
# 1       771155  Female   24                      6.2  Endurance training
# 2       231932    Male   22                      7.4            Fat loss
#
#   Preferred Sports Drink Type  Average Weekly Consumption (Bottles)
# 0                 Electrolyte                                    10
# 1                 Electrolyte                                    11
# 2                 Electrolyte                                    12

# %% [markdown]
# ### Data Overview

# %%
fitness.describe()
# Out:
#          Customer ID          Age  Hours at Gym (per week)  \
# count    1000.000000  1000.000000               935.000000
# mean   538112.094000    27.127000                 6.148663
# std    262574.257707     5.017773                 1.283104
# min    100404.000000    18.000000                 3.000000
# 25%    301536.000000    23.000000                 5.300000
# 50%    538556.500000    27.000000                 6.100000
# 75%    762517.000000    31.000000                 7.100000
# max    999684.000000    44.000000                10.300000
#
#        Gym Membership Length (years)  Calorie Intake
# count                    1000.000000      961.000000
# mean                        2.507000     2295.334027
# std                         1.652477      437.179461
# min                         0.000000     1500.000000
# 25%                         1.000000     1922.000000
# 50%                         2.000000     2321.000000
# 75%                         4.000000     2686.000000
# ...

# %%
chefsmeal.describe()
# Out:
#          Customer ID          Age  Hours at Gym (per week)  Calorie Intake  \
# count    1000.000000  1000.000000               935.000000      961.000000
# mean   538112.094000    27.127000                 6.148663     2295.334027
# std    262574.257707     5.017773                 1.283104      437.179461
# min    100404.000000    18.000000                 3.000000     1500.000000
# 25%    301536.000000    23.000000                 5.300000     1922.000000
# 50%    538556.500000    27.000000                 6.100000     2321.000000
# 75%    762517.000000    31.000000                 7.100000     2686.000000
# max    999684.000000    44.000000                10.300000     2997.000000
#
#        Average Spend per Meal Order
# count                    958.000000
# mean                      50.089927
# std                       10.923013
# min                       21.750000
# 25%                       42.072500
# 50%                       50.320000
# ...

# %%
pulsegear.describe()
# Out:
#          Customer ID          Age  Hours at Gym (per week)  \
# count    1000.000000  1000.000000               935.000000
# mean   538112.094000    27.127000                 6.148663
# std    262574.257707     5.017773                 1.283104
# min    100404.000000    18.000000                 3.000000
# 25%    301536.000000    23.000000                 5.300000
# 50%    538556.500000    27.000000                 6.100000
# 75%    762517.000000    31.000000                 7.100000
# max    999684.000000    44.000000                10.300000
#
#        Average Spend on Apparel ($/year)
# count                         1000.00000
# mean                           700.07309
# std                            191.33611
# min                              0.00000
# 25%                            585.00500
# 50%                            713.31500
# 75%                            836.90500
# max                           1152.37000

# %%
coreboost.describe()
# Out:
#          Customer ID          Age  Hours at Gym (per week)  \
# count    1000.000000  1000.000000               935.000000
# mean   538112.094000    27.127000                 6.148663
# std    262574.257707     5.017773                 1.283104
# min    100404.000000    18.000000                 3.000000
# 25%    301536.000000    23.000000                 5.300000
# 50%    538556.500000    27.000000                 6.100000
# 75%    762517.000000    31.000000                 7.100000
# max    999684.000000    44.000000                10.300000
#
#        Average Weekly Consumption (Bottles)
# count                           1000.000000
# mean                              10.142000
# std                                2.498415
# min                                4.000000
# 25%                                8.000000
# 50%                               10.000000
# 75%                               12.000000
# max                               20.000000

# %%
fitness.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer ID                    1000 non-null   int64
#  1   Gender                         1000 non-null   object
#  2   Age                            1000 non-null   int64
#  3   Hours at Gym (per week)        935 non-null    float64
#  4   Fitness Goal                   1000 non-null   object
#  5   Gym Membership Length (years)  1000 non-null   int64
#  6   Calorie Intake                 961 non-null    float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 54.8+ KB

# %%
fitness.isnull().sum()
# Out:
# Customer ID                       0
# Gender                            0
# Age                               0
# Hours at Gym (per week)          65
# Fitness Goal                      0
# Gym Membership Length (years)     0
# Calorie Intake                   39
# dtype: int64

# %%
chefsmeal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Customer ID                   1000 non-null   int64
#  1   Gender                        1000 non-null   object
#  2   Age                           1000 non-null   int64
#  3   Hours at Gym (per week)       935 non-null    float64
#  4   Fitness Goal                  1000 non-null   object
#  5   Calorie Intake                961 non-null    float64
#  6   Dietary Preferences           958 non-null    object
#  7   Average Spend per Meal Order  958 non-null    float64
# dtypes: float64(3), int64(2), object(3)
# memory usage: 62.6+ KB

# %%
chefsmeal.isnull().sum()
# Out:
# Customer ID                      0
# Gender                           0
# Age                              0
# Hours at Gym (per week)         65
# Fitness Goal                     0
# Calorie Intake                  39
# Dietary Preferences             42
# Average Spend per Meal Order    42
# dtype: int64

# %%
pulsegear.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Customer ID                        1000 non-null   int64
#  1   Gender                             1000 non-null   object
#  2   Age                                1000 non-null   int64
#  3   Hours at Gym (per week)            935 non-null    float64
#  4   Fitness Goal                       1000 non-null   object
#  5   Average Spend on Apparel ($/year)  1000 non-null   float64
#  6   Type of Apparel Purchased          952 non-null    object
#  7   Primary Apparel Purchase Channel   1000 non-null   object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 62.6+ KB

# %%
pulsegear.isnull().sum()
# Out:
# Customer ID                           0
# Gender                                0
# Age                                   0
# Hours at Gym (per week)              65
# Fitness Goal                          0
# Average Spend on Apparel ($/year)     0
# Type of Apparel Purchased            48
# Primary Apparel Purchase Channel      0
# dtype: int64

# %%
coreboost.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Customer ID                           1000 non-null   int64
#  1   Gender                                1000 non-null   object
#  2   Age                                   1000 non-null   int64
#  3   Hours at Gym (per week)               935 non-null    float64
#  4   Fitness Goal                          1000 non-null   object
#  5   Preferred Sports Drink Type           946 non-null    object
#  6   Average Weekly Consumption (Bottles)  1000 non-null   int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 54.8+ KB

# %%
coreboost.isnull().sum()
# Out:
# Customer ID                              0
# Gender                                   0
# Age                                      0
# Hours at Gym (per week)                 65
# Fitness Goal                             0
# Preferred Sports Drink Type             54
# Average Weekly Consumption (Bottles)     0
# dtype: int64

# %% [markdown]
# ### Delete Rows with Null Values

# %%
fitness = fitness.dropna(how='any',axis=0)
fitness.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 897 entries, 1 to 999
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer ID                    897 non-null    int64
#  1   Gender                         897 non-null    object
#  2   Age                            897 non-null    int64
#  3   Hours at Gym (per week)        897 non-null    float64
#  4   Fitness Goal                   897 non-null    object
#  5   Gym Membership Length (years)  897 non-null    int64
#  6   Calorie Intake                 897 non-null    float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 56.1+ KB

# %%
chefsmeal = chefsmeal.dropna(how='any',axis=0)
chefsmeal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 823 entries, 1 to 999
# Data columns (total 8 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Customer ID                   823 non-null    int64
#  1   Gender                        823 non-null    object
#  2   Age                           823 non-null    int64
#  3   Hours at Gym (per week)       823 non-null    float64
#  4   Fitness Goal                  823 non-null    object
#  5   Calorie Intake                823 non-null    float64
#  6   Dietary Preferences           823 non-null    object
#  7   Average Spend per Meal Order  823 non-null    float64
# dtypes: float64(3), int64(2), object(3)
# memory usage: 57.9+ KB

# %%
pulsegear = pulsegear.dropna(how='any',axis=0)
pulsegear.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 888 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Customer ID                        888 non-null    int64
#  1   Gender                             888 non-null    object
#  2   Age                                888 non-null    int64
#  3   Hours at Gym (per week)            888 non-null    float64
#  4   Fitness Goal                       888 non-null    object
#  5   Average Spend on Apparel ($/year)  888 non-null    float64
#  6   Type of Apparel Purchased          888 non-null    object
#  7   Primary Apparel Purchase Channel   888 non-null    object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 62.4+ KB

# %%
coreboost = coreboost.dropna(how='any',axis=0)
coreboost.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 886 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Customer ID                           886 non-null    int64
#  1   Gender                                886 non-null    object
#  2   Age                                   886 non-null    int64
#  3   Hours at Gym (per week)               886 non-null    float64
#  4   Fitness Goal                          886 non-null    object
#  5   Preferred Sports Drink Type           886 non-null    object
#  6   Average Weekly Consumption (Bottles)  886 non-null    int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 55.4+ KB

# %% [markdown]
# ## EDA

# %% [markdown]
# ### FlexField Fitness

# %%
fitness.hist(bins=50,figsize=(20,15))
plt.show()

# %%
numerical_cols_fitness = ['Age', 'Hours at Gym (per week)', 'Gym Membership Length (years)', 'Calorie Intake']
plt.figure(figsize=(8,6))
sns.heatmap(fitness[numerical_cols_fitness].corr(),cmap='YlGnBu',annot=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
categorical_columns = fitness.select_dtypes(include=['object']).columns

for column in categorical_columns:
    plt.figure(figsize=(8, 6))
    sns.countplot(x=column, data=fitness)
    plt.title(f'Count of {column}')
    plt.show()

# %%
ct = pd.crosstab([fitness['Gender']], fitness['Fitness Goal'])

sns.heatmap(ct, annot=True, cmap='coolwarm')
plt.title('Heatmap of Gender, Fitness Goal')
plt.show()

# %% [markdown]
# ### Chef's Meal

# %%
chefsmeal.hist(bins=50,figsize=(20,15))
plt.show()

# %%
numerical_cols_chefsmeal = ['Age', 'Hours at Gym (per week)', 'Calorie Intake', 'Average Spend per Meal Order']
plt.figure(figsize=(8,6))
sns.heatmap(chefsmeal[numerical_cols_chefsmeal].corr(),cmap='YlGnBu',annot=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
categorical_columns = chefsmeal.select_dtypes(include=['object']).columns

for column in categorical_columns:
    plt.figure(figsize=(8, 6))
    sns.countplot(x=column, data=chefsmeal)
    plt.title(f'Count of {column}')
    plt.show()

# %%
ct = pd.crosstab([chefsmeal['Gender'], chefsmeal['Dietary Preferences']], chefsmeal['Fitness Goal'])

sns.heatmap(ct, annot=True, cmap='coolwarm')
plt.title('Heatmap of Gender, Fitness Goal, and Dietary Preferences')
plt.show()

# %% [markdown]
# ### PulseGear

# %%
pulsegear.hist(bins=50,figsize=(20,15))
plt.show()

# %%
numerical_cols_pulsegear = ['Age', 'Hours at Gym (per week)', 'Average Spend on Apparel ($/year)']
plt.figure(figsize=(8,6))
sns.heatmap(pulsegear[numerical_cols_pulsegear].corr(),cmap='YlGnBu',annot=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
categorical_columns = pulsegear.select_dtypes(include=['object']).columns

for column in categorical_columns:
    plt.figure(figsize=(8, 6))
    sns.countplot(x=column, data=pulsegear)
    plt.title(f'Count of {column}')
    plt.show()

# %%
ct = pd.crosstab([pulsegear['Gender'], pulsegear['Type of Apparel Purchased']], pulsegear['Fitness Goal'])

sns.heatmap(ct, annot=True, cmap='coolwarm')
plt.title('Heatmap of Gender, Fitness Goal, and Type of Apparel Purchased')
plt.show()

# %%
ct = pd.crosstab([pulsegear['Type of Apparel Purchased']], pulsegear['Primary Apparel Purchase Channel'])

sns.heatmap(ct, annot=True, cmap='coolwarm')
plt.title('Heatmap of Primary Apparel Purchase Channel and Type of Apparel Purchased')
plt.show()

# %% [markdown]
# ### CoreBoost

# %%
coreboost.hist(bins=50,figsize=(20,15))
plt.show()

# %%
numerical_cols_coreboost = ['Age', 'Hours at Gym (per week)', 'Average Weekly Consumption (Bottles)']
plt.figure(figsize=(8,6))
sns.heatmap(coreboost[numerical_cols_coreboost].corr(),cmap='YlGnBu',annot=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
categorical_columns = coreboost.select_dtypes(include=['object']).columns

for column in categorical_columns:
    plt.figure(figsize=(8, 6))
    sns.countplot(x=column, data=coreboost)
    plt.title(f'Count of {column}')
    plt.show()

# %%
ct = pd.crosstab([coreboost['Gender'], coreboost['Preferred Sports Drink Type']], coreboost['Fitness Goal'])

sns.heatmap(ct, annot=True, cmap='coolwarm')
plt.title('Heatmap of Gender, Fitness Goal, and Preferred Sports Drink Type')
plt.show()
